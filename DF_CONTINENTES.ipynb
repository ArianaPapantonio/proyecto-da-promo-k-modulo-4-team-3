# %%
##Importamos librerias 

import pandas as pd
import numpy as np
import requests
import warnings 

pd.set_option('display.max_columns', None)

# %%
df_america = pd.read_csv('/mnt/c/Users/arian/Documents/Adalab/Modulo 4/proyecto-da-promo-k-modulo-4-team-3/files/América_LGBTQ_Con_Datos_Completos.csv')
df_america.head()
# Out:
#                 País Religión Predominante     Influencia Cultural  \
# 0  Antigua y Barbuda          Cristianismo  Occidental Progresista
# 1          Argentina          Cristianismo  Occidental Progresista
# 2            Bahamas          Cristianismo  Occidental Progresista
# 3           Barbados          Cristianismo  Occidental Progresista
# 4             Belice          Cristianismo  Occidental Progresista
#
#    Nivel Económico (PIB per cápita) Legalidad de la Homosexualidad  \
# 0                             10000                          Legal
# 1                             15000                         Ilegal
# 2                             20000                          Legal
# 3                             10000                         Ilegal
# 4                             15000                          Legal
#
#   Matrimonio Igualitario Protección contra Discriminación  \
# 0                     Sí                               Sí
# ...

# %%
df_asia = pd.read_csv('/mnt/c/Users/arian/Documents/Adalab/Modulo 4/proyecto-da-promo-k-modulo-4-team-3/files/Asia_LGBTQ_Con_Datos_Completos.csv')
df_asia.head()
# Out:
#              País Religión Predominante     Influencia Cultural  \
# 0      Afganistán          Cristianismo  Occidental Progresista
# 1  Arabia Saudita          Cristianismo  Occidental Progresista
# 2         Armenia          Cristianismo  Occidental Progresista
# 3      Azerbaiyán          Cristianismo  Occidental Progresista
# 4       Bangladés          Cristianismo  Occidental Progresista
#
#    Nivel Económico (PIB per cápita) Legalidad de la Homosexualidad  \
# 0                             10000                          Legal
# 1                             15000                         Ilegal
# 2                             20000                          Legal
# 3                             10000                         Ilegal
# 4                             15000                          Legal
#
#   Matrimonio Igualitario Protección contra Discriminación  \
# 0                     Sí                               Sí
# ...

# %%
df_africa = pd.read_csv('/mnt/c/Users/arian/Documents/Adalab/Modulo 4/proyecto-da-promo-k-modulo-4-team-3/files/África_LGBTQ_Con_Datos_Completos.csv')
df_africa.head()
# Out:
#            País Religión Predominante     Influencia Cultural  \
# 0        Angola          Cristianismo  Occidental Progresista
# 1       Argelia          Cristianismo  Occidental Progresista
# 2         Benín          Cristianismo  Occidental Progresista
# 3      Botsuana          Cristianismo  Occidental Progresista
# 4  Burkina Faso          Cristianismo  Occidental Progresista
#
#    Nivel Económico (PIB per cápita) Legalidad de la Homosexualidad  \
# 0                             10000                          Legal
# 1                             15000                         Ilegal
# 2                             20000                          Legal
# 3                             10000                         Ilegal
# 4                             15000                          Legal
#
#   Matrimonio Igualitario Protección contra Discriminación  \
# 0                     Sí                               Sí
# 1                     No                               No
# ...

# %%
df_europa = pd.read_csv('/mnt/c/Users/arian/Documents/Adalab/Modulo 4/proyecto-da-promo-k-modulo-4-team-3/files/Europa_LGBTQ_Con_Datos_Completos.csv')
df_europa.head()
# Out:
#        País Religión Predominante     Influencia Cultural  \
# 0   Albania          Cristianismo  Occidental Progresista
# 1  Alemania          Cristianismo  Occidental Progresista
# 2   Andorra          Cristianismo  Occidental Progresista
# 3   Armenia          Cristianismo  Occidental Progresista
# 4   Austria          Cristianismo  Occidental Progresista
#
#    Nivel Económico (PIB per cápita) Legalidad de la Homosexualidad  \
# 0                             10000                          Legal
# 1                             15000                         Ilegal
# 2                             20000                          Legal
# 3                             10000                         Ilegal
# 4                             15000                          Legal
#
#   Matrimonio Igualitario Protección contra Discriminación  \
# 0                     Sí                               Sí
# 1                     No                               No
# ...

# %%
df_oceania = pd.read_csv('/mnt/c/Users/arian/Documents/Adalab/Modulo 4/proyecto-da-promo-k-modulo-4-team-3/files/Oceanía_LGBTQ_Con_Datos_Completos.csv')
df_oceania.head()
# Out:
#              País Religión Predominante     Influencia Cultural  \
# 0       Australia          Cristianismo  Occidental Progresista
# 1            Fiyi          Cristianismo  Occidental Progresista
# 2  Islas Marshall          Cristianismo  Occidental Progresista
# 3   Islas Salomón          Cristianismo  Occidental Progresista
# 4        Kiribati          Cristianismo  Occidental Progresista
#
#    Nivel Económico (PIB per cápita) Legalidad de la Homosexualidad  \
# 0                             10000                          Legal
# 1                             15000                         Ilegal
# 2                             20000                          Legal
# 3                             10000                         Ilegal
# 4                             15000                          Legal
#
#   Matrimonio Igualitario Protección contra Discriminación  \
# 0                     Sí                               Sí
# ...

# %%
df_europa['Continente'] = 'Europa'

# %%
df_oceania['Continente'] = 'Oceania'

# %%
df_africa['Continente'] = 'Africa'

# %%
df_asia['Continente'] = 'Asia'

# %%
df_america['Continente'] = 'America'

# %%
df_continentes = pd.concat([df_oceania, df_africa, df_america, df_asia, df_europa], ignore_index=True)

# %%
df_continentes['Continente'].unique()
# Out:
# array(['Oceania', 'Africa', 'America', 'Asia', 'Europa'], dtype=object)

# %%
df_legalidad = pd.read_csv('/mnt/c/Users/arian/Documents/Adalab/Modulo 4/proyecto-da-promo-k-modulo-4-team-3/LegalidadLGTBIQA+.csv',index_col=0)
df_legalidad.head(3)
# Out:
#           país  índice de igualdad legal legalidad_colectivo_lgbtiq+  \
# 0  Afghanistan                      0.00                          No
# 2      Albania                     62.27                          Si
# 3      Algeria                      3.42                          No
#
#    fecha_despenalización     pena_máxima constitución protección_amplia  \
# 0                      0  Pena de muerte           No                No
# 2                   1995     Desconocido           No                Si
# 3                      0          2 años           No                No
#
#   empleo crimen_odio incitación prohibición_terapias matrimonio_igualitario  \
# 0     No          No         No                   No                     No
# 2     Si          Si         Si                   No                     No
# 3     No          No         No                   No                     No
#
#   uniones_civiles adopción_conjunta adopción_segundo_progenitor
# ...

# %%
len(df_continentes['País'])
# Out:
# 202

# %%
len(df_legalidad['país'])
# Out:
# 204

# %%
df_continentes.head(2)
# Out:
#         País Religión Predominante     Influencia Cultural  \
# 0  Australia          Cristianismo  Occidental Progresista
# 1       Fiyi          Cristianismo  Occidental Progresista
#
#    Nivel Económico (PIB per cápita) Legalidad de la Homosexualidad  \
# 0                             10000                          Legal
# 1                             15000                         Ilegal
#
#   Matrimonio Igualitario Protección contra Discriminación  \
# 0                     Sí                               Sí
# 1                     No                               No
#
#    Índice de Felicidad  PIB per cápita  Índice de Desarrollo  \
# 0                    5           10000                  0.50
# 1                    6           13000                  0.55
#
#    Índice de Desarrollo Humano (IDH)  \
# 0                               0.60
# 1                               0.64
#
#                  Observaciones Culturales y Sociales Continente
# ...

# %%
df_continentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   País                                 202 non-null    object
#  1   Religión Predominante                202 non-null    object
#  2   Influencia Cultural                  202 non-null    object
#  3   Nivel Económico (PIB per cápita)     202 non-null    int64
#  4   Legalidad de la Homosexualidad       202 non-null    object
#  5   Matrimonio Igualitario               202 non-null    object
#  6   Protección contra Discriminación     202 non-null    object
#  7   Índice de Felicidad                  202 non-null    int64
#  8   PIB per cápita                       202 non-null    int64
#  9   Índice de Desarrollo                 202 non-null    float64
#  10  Índice de Desarrollo Humano (IDH)    202 non-null    float64
# ...

# %%
df_continentes.drop(columns=['Observaciones Culturales y Sociales'], inplace=True)
# Guardamos los cambios
df_continentes.rename(columns=lambda x: x.lower(), inplace=True)

# %%
df_continentes.head(2)
# Out:
#         país religión predominante     influencia cultural  \
# 0  Australia          Cristianismo  Occidental Progresista
# 1       Fiyi          Cristianismo  Occidental Progresista
#
#    nivel económico (pib per cápita) legalidad de la homosexualidad  \
# 0                             10000                          Legal
# 1                             15000                         Ilegal
#
#   matrimonio igualitario protección contra discriminación  \
# 0                     Sí                               Sí
# 1                     No                               No
#
#    índice de felicidad  pib per cápita  índice de desarrollo  \
# 0                    5           10000                  0.50
# 1                    6           13000                  0.55
#
#    índice de desarrollo humano (idh) continente
# 0                               0.60    Oceania
# 1                               0.64    Oceania

# %%
df_continentes.to_csv('Continentes.csv')
